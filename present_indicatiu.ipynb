# %% [markdown]
# ## Objectiu: El Sam m'ha demanat que fes una baralla que només contingués els verbs del present de l'indicatiu

# %%
import pandas as pd

# %%
df = pd.read_csv('table_to_make_cards.csv', sep='|')

# just get present ind.
print(len(df.index))
df = df.loc[(df.tense == 'P')&\
            (df.mood == 'I')]
print(len(df.index))
# Out:
# 3500
# 390

# %%
df.to_csv('table_to_make_cards_pres_ind.csv', sep='|')
